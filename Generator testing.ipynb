# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Feb 16 18:25:48 2021

@author: omer_
"""
from tensorflow.keras.models import load_model
from numpy.random import randn
from matplotlib import pyplot
import cv2
 
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input
 
# create and save a plot of generated images (reversed grayscale)
def show_plot(examples, n):
	# plot images
	for i in range(n * n):
		# define subplot
		pyplot.subplot(n, n, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(examples[i, :, :, 0], cmap='gray')
	pyplot.show()
 
# load model
model = load_model(r'D:\OneDrive - Universitetet i Stavanger\Masters Thesis\Generator\generator2000.h5')
# generate images
latent_points = generate_latent_points(100, 1000)
# generate images
X = model.predict(latent_points)
print(X.shape)
re_sized = []
for i in range (len (X)): 
    x = cv2.merge((X[i, :, :, 0],X[i, :, :, 0],X[i, :, :, 0]))
    re_sized.append(x)
X = np.asarray(re_sized)
print(X.shape)
# plot the result
show_plot(X,2)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# (1000, 128, 128, 1)
# (1000, 128, 128, 3)

# %%
model = load_model(r'D:\OneDrive - Universitetet i Stavanger\Masters Thesis\New folder\generator2000.h5')
# generate images
latent_points = generate_latent_points(100, 100)
# generate images
X = model.predict(latent_points)
# plot the result
show_plot(X,10)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
b = show_plot(X, 10)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-18-4e59cee5fa3d> in <module>
#       1 b = show_plot(X, 10)
# ----> 2 cv2.imwrite('image_dc1.jpg', b)
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-h4wtvo23\opencv\modules\imgcodecs\src\loadsave.cpp:738: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
model = load_model(r'D:\OneDrive - Universitetet i Stavanger\Masters Thesis\Generator for 128 latent points\generator1000.h5')
# generate images
latent_points = generate_latent_points(100, 100)
# generate images
X = model.predict(latent_points)
# plot the result
show_plot(X, 3)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
import numpy as np 
a = np.array([[[0.0, 1.0, 0.0]],
              [[1.0, 1.0, 1.0 ]],
              [[1.0, 0.0, 1.0]]])

# %%
len (x)
# Out:
# 1000

# %%
# a = (x[1,:,:,0])
for i in range(len(X)):
    cv2.imwrite('D:/Generator/{}.jpg'.format (i) ,255*X[i,:,:,0])

# %%
for i in range(1000):
    cv2.imwrite(r'D:\OneDrive - Universitetet i Stavanger\Masters Thesis\training\Non_Significant_gen\{}.jpg'.format(i),255*x[i, :, :, 0])

# %%
for i in range(0,10,2):
     print (i)
# Out:
# 0
# 2
# 4
# 6
# 8
